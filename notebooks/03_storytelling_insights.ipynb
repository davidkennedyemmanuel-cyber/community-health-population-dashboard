# %% [markdown]
# # Data Storytelling & Insights

# %% [markdown]
# ## Context
# Global health indicators reflect community wellbeing.

# %% [markdown]
# ## Observations
# - Life expectancy rises
# - Mortality declines with sustained spending

# %% [markdown]
# ## Insights
# Consistency matters more than short-term spikes.

# %% [markdown]
# ## Recommendations
# - Invest in primary healthcare
# - Maintain long-term funding
